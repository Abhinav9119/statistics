# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
import seaborn as sns
from scipy.stats import zscore

# %%
df1=pd.read_csv("Men ODI Player Innings Stats - 20th Century.csv")
df2=pd.read_csv("Men ODI Player Innings Stats - 21st Century.csv")

# %%
df=pd.concat([df1,df2])

# %%
df
# Out:
#            Innings Player Innings Runs Scored Innings Runs Scored Num  \
# 0                RA Smith                167*                     167
# 1                DI Gower                 158                     158
# 2               CWJ Athey                142*                     142
# 3                GA Gooch                 142                     142
# 4                DL Amiss                 137                     137
# ...                   ...                 ...                     ...
# 327323  Najibullah Zadran                 NaN                     NaN
# 327324        Rahmat Shah                 NaN                     NaN
# 327325  Hazratullah Zazai                 NaN                     NaN
# 327326     Ibrahim Zadran                 NaN                     NaN
# 327327      Ikram Alikhil                 NaN                     NaN
#
#        Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag  \
# ...

# %%
df_virat=df[df['Innings Player']=="V Kohli"]
df_virat
# Out:
#        Innings Player Innings Runs Scored Innings Runs Scored Num  \
# 38091         V Kohli                 183                     183
# 38097         V Kohli                160*                     160
# 38100         V Kohli                157*                     157
# 38101         V Kohli                154*                     154
# 38116         V Kohli                 140                     140
# ...               ...                 ...                     ...
# 277054        V Kohli                 NaN                     NaN
# 277060        V Kohli                 NaN                     NaN
# 277064        V Kohli                 NaN                     NaN
# 277072        V Kohli                 NaN                     NaN
# 277076        V Kohli                 NaN                     NaN
#
#        Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag  \
# 38091                     211                  1.0                   0.0
# ...

# %%
new_df=df_virat[['Innings Player','Innings Runs Scored Num']]
new_df.head()
# Out:
#       Innings Player Innings Runs Scored Num
# 38091        V Kohli                     183
# 38097        V Kohli                     160
# 38100        V Kohli                     157
# 38101        V Kohli                     154
# 38116        V Kohli                     140

# %%
new_df['Innings Runs Scored Num']=new_df['Innings Runs Scored Num'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 new_df['Innings Runs Scored Num']=new_df['Innings Runs Scored Num'].astype(int)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
new_df.info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1488 entries, 38091 to 277076
# Data columns (total 2 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Innings Player           1488 non-null   object
#  1   Innings Runs Scored Num  1488 non-null   object
# dtypes: object(2)
# memory usage: 34.9+ KB
