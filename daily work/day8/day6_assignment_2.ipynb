# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
import seaborn as sns
import random

# %%
df1=pd.read_csv("marathon_results_2015.csv")
df2=pd.read_csv("marathon_results_2016.csv")
df3=pd.read_csv("marathon_results_2017.csv")

# %%
df=pd.concat([df1,df2,df3])
df.head()
# Out:
#    Unnamed: 0 Bib                   Name  Age M/F         City State Country  \
# 0         0.0   3         Desisa, Lelisa   25   M         Ambo   NaN     ETH
# 1         1.0   4  Tsegay, Yemane Adhane   30   M  Addis Ababa   NaN     ETH
# 2         2.0   8         Chebet, Wilson   29   M     Marakwet   NaN     KEN
# 3         3.0  11       Kipyego, Bernard   28   M      Eldoret   NaN     KEN
# 4         4.0  10          Korir, Wesley   32   M       Kitale   NaN     KEN
#
#   Citizen Unnamed: 9  ...      30K      35K      40K     Pace Proj Time  \
# 0     NaN        NaN  ...  1:32:00  1:47:59  2:02:39  0:04:56         -
# 1     NaN        NaN  ...  1:31:59  1:47:59  2:02:42  0:04:58         -
# 2     NaN        NaN  ...  1:32:00  1:47:59  2:03:01  0:04:59         -
# 3     NaN        NaN  ...  1:32:00  1:48:03  2:03:47  0:05:00         -
# 4     NaN        NaN  ...  1:32:00  1:47:59  2:03:27  0:05:00         -
#
#   Official Time Overall Gender Division Unnamed: 8
# ...

# %%
sample=df.sample(frac=0.10, replace=True, random_state=1)
sample.head()
# Out:
#        Unnamed: 0    Bib               Name  Age M/F         City State  \
# 24480     24480.0  26801     Shah, Vivek M.   40   M    Wellesley    MA
# 5192       5192.0   8545    Martin, Bruce V   50   M   St. George    UT
# 23459         NaN  22162  Bloomer, Helen J.   50   F   Birmingham   NaN
# 20121     20121.0  16968     Smith, Madolyn   26   F  Neutral Bay   NaN
# 21440     21440.0  24258   Shea, Patrick J.   27   M       Boston    MA
#
#       Country Citizen Unnamed: 9  ...      30K      35K      40K     Pace  \
# 24480     USA     NaN        NaN  ...  3:27:34  4:10:12  4:52:06  0:11:48
# 5192      USA     NaN        NaN  ...  2:14:36  2:38:12  3:01:55  0:07:21
# 23459     GBR     NaN        NaN  ...  3:21:22  3:57:32  4:31:12  0:10:57
# 20121     AUS     NaN        NaN  ...  2:57:50  3:33:31  4:10:24  0:10:04
# 21440     USA     NaN        NaN  ...  2:50:10  3:25:05  4:03:06  0:09:48
#
#       Proj Time Official Time Overall Gender Division Unnamed: 8
# ...

# %%
def systematic_sampling(df,step):
    indexes=np.arange(0,len(df),step=step)
    systematic_sample=df.iloc[indexes]
    return systematic_sample


systematic_sampling=systematic_sampling(df,7)
systematic_sampling.head()
# Out:
#     Unnamed: 0  Bib                  Name  Age M/F               City State  \
# 0          0.0    3        Desisa, Lelisa   25   M               Ambo   NaN
# 7          7.0    1       Keflezighi, Meb   39   M          San Diego    CA
# 14        14.0   76         Goffi, Danilo   42   M  Parabiago - Milan   NaN
# 21        21.0   32  Zywicki, Benjamin P.   26   M         Louisville    CO
# 28        28.0  106          Glaz, Daniel   32   M            Chicago    IL
#
#    Country Citizen Unnamed: 9  ...      30K      35K      40K     Pace  \
# 0      ETH     NaN        NaN  ...  1:32:00  1:47:59  2:02:39  0:04:56
# 7      USA     NaN        NaN  ...  1:31:59  1:47:59  2:04:58  0:05:04
# 14     ITA     NaN        NaN  ...  1:38:02  1:54:55  2:11:25  0:05:18
# 21     USA     NaN        NaN  ...  1:38:46  1:56:05  2:13:25  0:05:24
# 28     USA     NaN        NaN  ...  1:42:19  1:59:50  2:17:03  0:05:32
#
#    Proj Time Official Time Overall Gender Division Unnamed: 8
# ...

# %%
df_male=df[df["M/F"]=="M"]
df_female=df[df["M/F"]=="F"]

# %%
males_s=df_male.sample(frac=0.10, replace=True, random_state=1)
female_s=df_female.sample(frac=0.10,replace=True,random_state=1)
female_s
# Out:
#        Unnamed: 0    Bib                  Name  Age M/F  \
# 20686     20686.0  19330     Farr, Patricia A.   45   F
# 2175          NaN   3066          Casto, Katie   33   F
# 14958     14958.0  24652    Goulian, Debora T.   56   F
# 19795     19795.0  24020            Daly, Dana   57   F
# 19284     19284.0  24612    Crowley, Barbara J   58   F
# ...           ...    ...                   ...  ...  ..
# 11855     11855.0  22525        Purhar, Neelam   50   F
# 23492     23492.0  29315         Bufe, Katelyn   31   F
# 14344         NaN  26676  Figueroa Toro, Marta   46   F
# 20903         NaN  22061    Larson, Victoria L   46   F
# 21779         NaN  27003     Leary, Caitlin R.   31   F
#
#                              City State Country Citizen Unnamed: 9  ...  \
# 20686  Belmont, Western Australia   NaN     AUS     NaN        NaN  ...
# 2175                   Louisville    KY     USA     NaN        NaN  ...
# 14958                    Kinnelon    NJ     USA     NaN        NaN  ...
# ...

# %%
final_sample=pd.concat([males_s,female_s])
final_sample
# Out:
#        Unnamed: 0    Bib                                  Name  Age M/F  \
# 4591       4591.0   1736                       Wire, Thomas W.   33   M
# 21122     21122.0   3542                          Brown, Doyle   43   M
# 5912       5912.0   4234                            Niv, David   44   M
# 3946       3946.0   8018  Azevedo Marques dos Santos, Jorge M.   47   M
# 10298     10298.0  14689                          Smith, Brian   50   M
# ...           ...    ...                                   ...  ...  ..
# 11855     11855.0  22525                        Purhar, Neelam   50   F
# 23492     23492.0  29315                         Bufe, Katelyn   31   F
# 14344         NaN  26676                  Figueroa Toro, Marta   46   F
# 20903         NaN  22061                    Larson, Victoria L   46   F
# 21779         NaN  27003                     Leary, Caitlin R.   31   F
#
#                 City State Country Citizen Unnamed: 9  ...      30K      35K  \
# ...

# %%
#cluster sampling

clusters = np.random.choice(df[""], size=2, replace=False)
cluster_sample = df[df['M/F'].isin(clusters)]

# %%
cluster_sample
# Out:
#        Unnamed: 0    Bib                      Name  Age M/F          City  \
# 0             0.0      3            Desisa, Lelisa   25   M          Ambo
# 1             1.0      4     Tsegay, Yemane Adhane   30   M   Addis Ababa
# 2             2.0      8            Chebet, Wilson   29   M      Marakwet
# 3             3.0     11          Kipyego, Bernard   28   M       Eldoret
# 4             4.0     10             Korir, Wesley   32   M        Kitale
# ...           ...    ...                       ...  ...  ..           ...
# 26405     26405.0  25166  Steinbach, Paula Eyvonne   61   F       Ontario
# 26406     26406.0  25178        Avelino, Andrew R.   25   M  Fayetteville
# 26407     26407.0  27086           Hantel, Johanna   57   F       Malvern
# 26408     26408.0  25268              Reilly, Bill   64   M      New York
# 26409     26409.0  25266             Rigsby, Scott   48   M    Alpharetta
#
#       State Country Citizen Unnamed: 9  ...      30K      35K      40K  \
# ...

# %%
df
# Out:
#        Unnamed: 0    Bib                      Name  Age M/F          City  \
# 0             0.0      3            Desisa, Lelisa   25   M          Ambo
# 1             1.0      4     Tsegay, Yemane Adhane   30   M   Addis Ababa
# 2             2.0      8            Chebet, Wilson   29   M      Marakwet
# 3             3.0     11          Kipyego, Bernard   28   M       Eldoret
# 4             4.0     10             Korir, Wesley   32   M        Kitale
# ...           ...    ...                       ...  ...  ..           ...
# 26405     26405.0  25166  Steinbach, Paula Eyvonne   61   F       Ontario
# 26406     26406.0  25178        Avelino, Andrew R.   25   M  Fayetteville
# 26407     26407.0  27086           Hantel, Johanna   57   F       Malvern
# 26408     26408.0  25268              Reilly, Bill   64   M      New York
# 26409     26409.0  25266             Rigsby, Scott   48   M    Alpharetta
#
#       State Country Citizen Unnamed: 9  ...      30K      35K      40K  \
# ...

# %% [markdown]
# cluster sampling find how many countries the athletes are from the select all records of half of the countries as sample in a new dataframe print the number of rows in the original dataframe and the new dataframe to conform (hint:use the np.random.choice() method)
